# %%
# from install_module_colab import install_module_colab
# install_module_colab()

# %%
from typing_extensions import TypedDict
from langgraph.graph import StateGraph, START, END

# %%
class SimpleState(TypedDict):
    input_text:str
    output_text:str

# %%
SimpleState(input_text="hello", output_text="hellooooo")
# Out:
# {'input_text': 'hello', 'output_text': 'hellooooo'}

# %%
def process_input(state:SimpleState) -> SimpleState:
    state['input_text'] = state['input_text'].upper()
    return state

def add_prefix(state:SimpleState) -> SimpleState:
    current_text = state['input_text']
    output = "" + state['output_text']
